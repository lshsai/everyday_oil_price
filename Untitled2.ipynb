# %%
import requests 
api_code = 'F739200410'
r2 = requests.get(f'http://www.opinet.co.kr/api/lowTop10.do?out=json&code={api_code}&prodcd=B027&area=01').json()
# Out:
# '\r\n                                \r\n\r\n \r\n{"RESULT":  \r\n{"OIL":[ \r\n           \r\n \r\n{"UNI_ID":"A0000335","PRICE":1229,"POLL_DIV_CD":"RTO","OS_NM":"원천주유소","VAN_ADR":"서울 성북구 장위동 75-604","NEW_ADR":"서울 성북구 돌곶이로 142 (장위동)","GIS_X_COOR":316565.00298,"GIS_Y_COOR":557374.99535},\t\t         \r\n\r\n                                         \r\n\r\n{"UNI_ID":"A0000983","PRICE":1236,"POLL_DIV_CD":"HDO","OS_NM":"형산석유(주)원주유소","VAN_ADR":"서울 양천구 신월동 199-5","NEW_ADR":"서울 양천구 남부순환로 408","GIS_X_COOR":296899.43014,"GIS_Y_COOR":548290.96783},\t\t         \r\n\r\n                                         \r\n\r\n{"UNI_ID":"A0004657","PRICE":1236,"POLL_DIV_CD":"RTO","OS_NM":"뉴신정주유소","VAN_ADR":"서울 강서구 화곡동 862-16","NEW_ADR":"서울 강서구 곰달래로 207(화곡동)","GIS_X_COOR":299091.02200,"GIS_Y_COOR":548321.99040},\t\t         \r\n\r\n                                         \r\n\r\n{"UNI_ID":"A0000519","PRICE":1236,"POLL_DIV_CD":"RTO","OS_NM":"화곡역주유소","VAN_ADR":"서울 강서구 화곡동 1076-14","NEW_ADR":"서울특별시 강서구  강서로 
# ...

# %%
a = r2.json()

# %%
a["RESULT"].
# Out:
# {'OIL': [{'UNI_ID': 'A0000335',
#    'PRICE': 1229,
#    'POLL_DIV_CD': 'RTO',
#    'OS_NM': '원천주유소',
#    'VAN_ADR': '서울 성북구 장위동 75-604',
#    'NEW_ADR': '서울 성북구 돌곶이로 142 (장위동)',
#    'GIS_X_COOR': 316565.00298,
#    'GIS_Y_COOR': 557374.99535},
#   {'UNI_ID': 'A0000983',
#    'PRICE': 1236,
#    'POLL_DIV_CD': 'HDO',
#    'OS_NM': '형산석유(주)원주유소',
#    'VAN_ADR': '서울 양천구 신월동 199-5',
#    'NEW_ADR': '서울 양천구 남부순환로 408',
#    'GIS_X_COOR': 296899.43014,
#    'GIS_Y_COOR': 548290.96783},
#   {'UNI_ID': 'A0004657',
#    'PRICE': 1236,
#    'POLL_DIV_CD': 'RTO',
#    'OS_NM': '뉴신정주유소',
#    'VAN_ADR': '서울 강서구 화곡동 862-16',
#    'NEW_ADR': '서울 강서구 곰달래로 207(화곡동)',
#    'GIS_X_COOR': 299091.022,
#    'GIS_Y_COOR': 548321.9904},
#   {'UNI_ID': 'A0000519',
#    'PRICE': 1236,
#    'POLL_DIV_CD': 'RTO',
#    'OS_NM': '화곡역주유소',
#    'VAN_ADR': '서울 강서구 화곡동 1076-14',
#    'NEW_ADR': '서울특별시 강서구  강서로 154 (화곡동)',
#    'GIS_X_COOR': 297830.02778,
#    'GIS_Y_COOR': 549333.51356},
# ...
